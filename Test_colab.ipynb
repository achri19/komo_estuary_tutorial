# %% [markdown]
# # **Delta-X Applications Workshop**

# %% [markdown]
# Get familiar with Google Colab, but it basically a cloud version of Jupyter Notebook.
#
# To use this notebook online, you will need to Colab accres to your google account and google drive.
#
# **All packages you need should load without any issues. When you run the cell below, there will be a few pop-ups asking you to grant acces to your Google accounts. If you don't accept, you won't be able to access the files needed for this tutorial.**
#
# Let us know if you have any issues.

# %%
# !pip install rasterio

import numpy as np
from osgeo import gdal
import pandas as pd
import rasterio
import matplotlib.pyplot as plt

import os

#For access to Google Drive files
from google.colab import files
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

#For saving to Google Drive
from google.colab import drive

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
Gdrive = GoogleDrive(gauth)

drive.mount('/content/drive',force_remount=True)
# Out:
# Requirement already satisfied: rasterio in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (1.2.10)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click>=4.0 in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (7.0)
# Requirement already satisfied: cligj>=0.5 in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: setuptools in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (46.0.0.post20200309)
# Requirement already satisfied: certifi in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (2019.11.28)
# Requirement already satisfied: numpy in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (1.18.1)
# Requirement already satisfied: click-plugins in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: attrs in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (19.3.0)
# Requirement already satisfied: affine in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (2.3.1)
# Requirement already satisfied: pyparsing>=2.1.6 in /Users/Alchrist/opt/anaconda3/lib/python3.7/site-packages (from snuggs>=1.4.1->rasterio) (2.4.6)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/t4/rxm4gf256g17r9g4y6cqt2gm0000gp/T/ipykernel_22200/1635425056.py in <module>
#      10
#      11 #For access to Google Drive files
# ---> 12 from google.colab import files
#      13 from pydrive.auth import GoogleAuth
#      14 from pydrive.drive import GoogleDrive
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# Before you can run the next step, you need to link the shared DeltaX_Workshop Google Drive Folder to your "My Drive".
#
# > This is done by going to https://drive.google.com/drive/folders/1KQIQPNowinFYQGd7SvpUE2sHPS0ALueV?usp=sharing
#
# > And then adding a shortcut to your drive
#
#
#
# ![colab_link.png](data:image/png;base64,...)

# %%
input_dir = '/content/drive/MyDrive/DeltaX_Workshop_2022/for_notebooks/'

# %% [markdown]
# Load a file

# %%
data = rasterio.open(input_dir + 'Test_Raster.tif')
# Normalize bands into 0.0 - 1.0 scale
def normalize(array):
    array_min, array_max = array.min(), array.max()
    return (array - array_min) / (array_max - array_min)

# Convert to numpy arrays
red = data.read(1)
green = data.read(2)
blue = data.read(3)

# Normalize band DN
red_norm = normalize(red)
green_norm = normalize(green)
blue_norm = normalize(blue)

# Stack bands
rbg = np.dstack((red_norm, green_norm,blue_norm))

# View the color composite
plt.imshow(rbg)
plt.savefig(f"{input_dir}/plot1.png")
